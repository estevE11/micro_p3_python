# %% [markdown]
# <table style="width:50%" >
# <tr>
#     <th style="text-align:left"><img  src="https://arqfestival.files.wordpress.com/2017/03/logo_tecnocampus.png?w=1120&h=214" ></th>
#     <th style="text-align:right">Programació de micros</th>
#   </tr>
#
# </table>

# %% [markdown]
# <h1 style="text-align:center"> PRÀCTICA 3 </h1>

# %% [markdown]
# <font color="blue"  face="verdana"> <h2 style="text-align:center">Introducció al Python</h2></font>
#
# **La pràctica es realitza amb Python 3**

# %% [markdown]
# <h2>Exercici 1</h2><br>
# Escriu un programa que demani a l'usuari que entri la seva edat en anys com un input(l'edat és un enter) i mostri per pantalla l'edat en nombre de dies. Suposa que tots els anys tenen 365 dies.<br>
# Per exemple si l'usuari entra: <strong><font color="green">22</font></strong><br>
# El programa mostrarà: <font color="green"><strong>has viscut 8030 dies</strong></font>

# %%
age = input("Introdueix la teva edat: ")
print("Has viscut " + str(int(age)*365))
# Out:
# Introdueix la teva edat: 20
# Has viscut 7300

# %% [markdown]
# <h2>Exercici 2</h2><br>
# Un triangle es pot classificar en funció de les longituds dels seus costats. Si té tots tres costats iguals és equilàter. Si té dos costats iguals isòsceles i si tots són diferents escalè. Escriu un programa que llegeixi els tres costats d’un triangle i et digui de quin tipus és.

# %%
c0 = input("Introdueix el primer costat: ")
c1 = input("Introdueix el segon costat: ")
c2 = input("Introdueix el tecer costat: ")

if c0 == c1 and c0 == c2:
  print("Triangle equilàter")
elif c0 == c1 or c0 == c2 or c1 == c2:
  print("Triangle isòceles")
else:
  print("Triangle escalè")
# Out:
# Introdueix el primer costat: 1
# Introdueix el segon costat: 1
# Introdueix el tecer costat: 1
# Triangle equilàter

# %% [markdown]
# <h2>Exercici 3</h2><br>
# L'índex de massa corporal s'utilitza per determinar si una persona té un pes normal, infrapès u obesitat. La fòrmula és: imc = m /l<sup>2</sup> on m és el pes en kilos i l és l'alçada. En funció del valor hi ha la següent classificació:
#
# *   menor a 18: infrapès
# *   entre 18 i 25 (ambdòs inclosos): normal
# *   major de 25: obesitat
#
# Escriu un programa que et demani el pes i l'alçada i indiqui la masa corporal i classificació en funció de la mateixa

# %%
w = int(input("Introdueix el pes(kg): "))
h = int(input("Introdueix l'alçada(cm): "))/100
imc = w/h**2

if imc < 18:
  print("Infrapès")
elif imc <= 25:
  print("Pes normal")
else:
  print("1Obesitat")
# Out:
# Introdueix el pes(kg): 78
# Introdueix l'alçada(cm): 180
# Pes normal

# %% [markdown]
# <h2>Exercici 4</h2><br>
# Escriu un programa que llegeixi tres nombres i els mostri en ordre ascendent

# %%
a = input("Primer nombre: ")
b = input("Segon nombre: ")
c = input("Tercer nombre: ")

print(min(min(a, b), c))

if a > b:
  print(max(b, c))
else:
  print(min(b, c))

print(max(max(a, b), c))
# Out:
# Primer nombre: 300
# Segon nombre: 3000
# Tercer nombre: 20
# 20
# 20
# 3000

# %% [markdown]
# <h2>Exercici 5</h2><br>
# Desenvolupa un programa que resolgui les equacions de segon grau.<br>
# Recordeu que l’expressió és:  ax<sup>2</sup> + bx + c = 0<br>
# El programa demanarà entrar: a, b, i  donarà les arrels reals de l’equació. <br>
# Recordeu que: $x = \displaystyle\frac{{ - b \pm \sqrt {b^2 - 4ac} }}{2a} $<br>
# <div>
# <table align="left" style="width:40%" text-align="center">
# <tr>
# <td>Per fer arrel:<br>
# <strong>import math</strong><br>
# <strong>math.sqrt()</strong></td>
# <tr>
# </table>
# </div>

# %%
import math

a = float(input("a: "))
b = float(input("b: "))
c = float(input("c: "))

part1 = math.sqrt(b**2 - 4*a*c)

x1 = (-b + part1)/2*a
x2 = (-b - part1)/2*a

print("x1 = " + str(x1))
print("x2 = " + str(x2))
# Out:
# a: 1
# b: 1
# c: -2
# x1 = 1.0
# x2 = -2.0

# %% [markdown]
# <h2>Exercici 6</h2><br>
# Escriu un programa que llegeixi quatre nombres(representant els quatre octets d'una adreça IP). Si tots els nombres estan en el rang correcte (valors entre 0 i 255) mostra l'adreça de la forma: aaa.bbb.ccc.ddd i quin tipus d'adreça és (classe A, classe B o classe C) i
# <img src="http://1.bp.blogspot.com/-VaHeBezXCvw/Tz0m8vI59pI/AAAAAAAAAJc/SUAEQmNiuN8/s320/Rangos+IP.jpg">
#
# Exemples del que s’hauria de veure de sortida:
# Si entrem els valors: 128, 128, 128, 128
# la sortida serà:
# l'adreça es: 128.128.128.128 i es una adreça de classe B

# %%
a = -1
while a > 255 or a < 0:
  a = int(input("Primer nombre: "))

b = -1
while b > 255 or b < 0:
  b = int(input("Segon nombre: "))

c = -1
while c > 255 or c < 0:
  c = int(input("Tercer nombre: "))

d = -1
while d > 255 or d < 0:
  d = int(input("Quart nombre: "))

t = ""

if a < 128:
  t = "A"
elif a < 192:
  t = "B"
elif a < 224:
  t = "C"
elif a < 240:
  t = "D"
else:
  t = "E"

print(("%d.%d.%d.%d" % (a, b, c, d)) + " es de classe " + t)
# Out:
# Primer nombre: 128
# Segon nombre: 128
# Tercer nombre: 128
# Quart nombre: 128
# 128.128.128.128 es de classe B

# %% [markdown]
# <h2>Exercici 7</h2><br>
# Un zoo determina el preu en funció de l’edat de la persona. Si la persona té 2 o menys anys entra gratis. Si l’edat està entre 3 i 12 inclosos, el preu és 14 €. Si té més de 12 i menys de 65 costa 23 € i pels jubilats costa 18 €.
# Es demana fer un programa que vagi llegint les edats de les persones d’un grup. Quan la persona que entra les edats escrigui ‘f’ es mostrarà el preu final que ha de pagar aquell grup.

# %%
def calc_price(age):
  if age <= 2:
    return 0
  
  if age >= 3 and age <= 12:
    return 14

  if age < 65:
    return 23

  return 18

price = 0
ipt = int(input("Edat: "))
while ipt != "f":
  price += calc_price(int(ipt))
  ipt = input("Edat: ")

print("El preu total es de %d€" % (price))
# Out:
# Edat: 12
# Edat: 80
# Edat: f
# El preu total es de 32€

# %% [markdown]
# <h2>Exercici 8</h2><br>
# Al 1937, un matemàtic alemany anomenat Lothar Collatz va formular la següent hipòtesi (encara no provada) que diu així:<br>
# 1. agafa un nombre enter positiu c0<br>
# 2. Si és parell fes c0 = c0 /2<br>
# 3. en cas contrari, si és imparell c0 = c0 x3 + 1<br>
# 4. si c0 és diferent a 1, torna al punt 2<br>
# La hipòtesi diu que independentment del nombre inicial, les iteracions convergeixen en el nombre 1.
# Fes un programa que comprovi el que diu la hipòtesi, de manera que donat un nombre ens vagi calculant els valors intermedis obtinguts fins arribar a 1 i el nombre de passos necessàries.<br>
# <u>Exemple:</u><br>
# Input: 15<br>
# Output:<br>
# 46,23,70,35,106,53,160,80,40,20,10,5,16,8,4,2,1<br>
# Passos: 17

# %%
c0 = int(input("Nombre enter: "))
steps = 0

while c0 != 1:
  if c0 % 2 == 0:
    c0 = c0/2
  else:
    c0 = c0 * 3 + 1
  steps += 1
  print(str(c0) + ",", end="")
print("\nPassos: " + str(steps))
# Out:
# Nombre enter: 46
# 23.0,70.0,35.0,106.0,53.0,160.0,80.0,40.0,20.0,10.0,5.0,16.0,8.0,4.0,2.0,1.0,
# Passos: 16

# %% [markdown]
# <h2>Exercici 9</h2><br>
# Es vol que donat un nombre de blocs per construir una piràmide s'indiqui l'alçada que tindrà la mateixa.
# Així per exemple si la piràmide tingués la forma següent:<br>
#  <br> &nbsp&nbsp&nbsp&nbsp  *
#  <br>  &nbsp&nbsp *&nbsp *
# <br>  &nbsp *&nbsp * &nbsp*
# <br>  El nombre de blocs és 6 i l'alçada 3
# <br> <u>Exemples:</u>
# <br> Input. Nombre de blocs: 6
# <br> Output. alçada: 3<br>
# ----------------------------
# <br>  Input.Nombre de blocs: 20
# <br>  Output. Alçada: 5<br>
# ----------------------------
# <br>  Input.Nombre de blocs 1000
# <br>  Output. Alçada: 44<br>
# ----------------------------
# <br>  Input. Nombre de blocs 2
#  <br> Output. Alçada: 1

# %%
n = int(input("Nombre de blocs: "))

height = 0
used = 0
while used < n:
  used += height+1
  height += 1

if used == n:
  print("Alçada: " + str(height))
else:
  print("Alçada: "  + str(height) + " pero no es pot fer una priamide exacte")
# Out:
# Nombre de blocs: 20
# Alçada: 6 pero no es pot fer una priamide exacte
